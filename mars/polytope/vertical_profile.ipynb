# %%
import earthkit.data
import earthkit.plots
from earthkit.regrid import interpolate
from earthkit.plots.interactive import Chart

import plotly.io as pio
pio.renderers.default = "notebook_connected"

# %% [markdown]
# # Polytope Vertical Profile Example
# ## Using Ensemble Prediction System (ENS) Data from FDB

# %% [markdown]
# <div style="border:2px solid #f39c12; background-color:#fcf8e3; padding:10px; border-radius:5px;">
#   <strong>⚠️ Warning:</strong> Operational FDB only retains data for 2 days in the past.
# </div>

# %%
request = {
    "class": "od",
    "stream" : "enfo",
    "type" : "pf",
    "date" : -1,  # Note: date must be within the last two days 
    "time" : "0000",
    "levtype" : "pl",
    "expver" : "0001", 
    "domain" : "g",
    "param" : "133", # Specific humidity (q)
    "number" : "1",
    "step" : "0",
    "feature" : {
        "type" : "verticalprofile",
        "points": [[38.9, -9.1]],
        "axes": "levelist",
        "range" : {
            "start" : 0,
            "end" : 1000,
        }
    },
}

data = earthkit.data.from_source(
    "polytope", "ecmwf-mars", request, stream=False, address='polytope.ecmwf.int')
# Out:
# 2025-10-12 13:14:41 - INFO - Key read from /home/maes/.polytopeapirc
# 2025-10-12 13:14:41 - INFO - Sending request...
# {'request': 'class: od\n'
#             'date: -1\n'
#             'domain: g\n'
#             "expver: '0001'\n"
#             'feature:\n'
#             '  axes: levelist\n'
#             '  points:\n'
#             '  - - 38.9\n'
#             '    - -9.1\n'
#             '  range:\n'
#             '    end: 1000\n'
#             '    start: 0\n'
#             '  type: verticalprofile\n'
#             'levtype: pl\n'
#             "number: '1'\n"
#             "param: '133'\n"
#             "step: '0'\n"
#             'stream: enfo\n'
#             "time: '0000'\n"
#             'type: pf\n',
#  'verb': 'retrieve'}
# 2025-10-12 13:14:41 - INFO - Polytope user key found in session cache for user maes
# 2025-10-12 13:14:41 - INFO - Request accepted. Please poll ./8eeada7e-67f8-4f5d-a1ba-1e199a2eeb6f for status
# 2025-10-12 13:14:41 - INFO - Polytope user key found in session cache for user maes
# 2025-10-12 13:14:41 - INFO - Checking request status (8eeada7e-67f8-4f5d-a1ba-1e199a2eeb6f)...
# 2025-10-12 13:14:41 - INFO - The current status of the request is 'queued'
# 2025-10-12 13:14:42 - INFO - The current status of the request is 'processing'
# 2025-10-12 13:14:45 - INFO - The current status of the request is 'processed'

# %%
dx = data.to_xarray()
dx
# Out:
# <xarray.Dataset> Size: 464B
# Dimensions:    (latitude: 1, longitude: 1, number: 1, datetime: 1, time: 1,
#                 levelist: 22)
# Coordinates:
#   * latitude   (latitude) float64 8B 38.91
#   * longitude  (longitude) float64 8B 350.9
#   * number     (number) int64 8B 1
#   * datetime   (datetime) <U20 80B '2025-10-11T00:00:00Z'
#   * time       (time) int64 8B 0
#   * levelist   (levelist) int64 176B 1 2 3 5 7 10 ... 500 600 700 850 925 1000
# Data variables:
#     q          (latitude, longitude, number, datetime, time, levelist) float64 176B ...
# Attributes:
#     class:          od
#     Forecast date:  2025-10-11T00:00:00Z
#     domain:         g
#     expver:         0001
#     levelist:       1
#     levtype:        pl
#     number:         1
#     stream:         enfo
#     type:           pf

# %%
chart = Chart()
fig = chart.fig
fig['layout']['yaxis']['autorange'] = "reversed"
chart.line(ds, y="levelist")
chart.fig.update_layout(yaxis={"title": "Pressure Levels (hPa)"})
chart.title("Vertical Profile of Specific Humidity over Bonn")

chart.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js" integrity="sha256-oy6Be7Eh6eiQFs5M7oXuPxxm9qbJXEtTpfSI93dW16Q=" crossorigin="anonymous"></script>                <div id="50d3e4c4-ef73-4603-a79b-e55b3d80026c" class="plotly-graph-div" style="height:750px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("50d3e4c4-ef73-4603-a79b-e55b3d80026c")) {                    Plotly.newPlot(                        "50d3e4c4-ef73-4603-a79b-e55b3d80026c",                        [{"x":{"dtype":"f8","bdata":"AAAAABIy0j4AAACANsTQPgAAAID\u002fZs8+AAAAgM+qzj4AAAAAdxrOPgAAAIDZbM0+AAAAANhLzD4AAACA9wPJPgAAAIDKWsg+AAAAAJ46yT4AAAAAAHHNPgAAAAAAVNI+AAAAAADC5D4AAAAAADz3PgAAAAAAuA0\u002fAAAAAADeND8AAAAAAG5HPwAAAAAAt1M\u002fAAAAAICmaz8AAAAAgGp\u002fPwAAAACAk4A\u002fAAAAAMBLgz8="},"y":{"dtype":"i2","bdata":"AQACAAMABQAHAAoAFAAeADIARgBkAJYAyAD6ACwBkAH0AVgCvAJSA50D6AM="},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks ...
